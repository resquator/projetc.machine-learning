# %%
import pyforest

import pyforest
from datetime import datetime
import json
from pandas.io.json import json_normalize
from collections import OrderedDict

from tagheuerdata import TagHeuerData

# %%
help(TagHeuerData)
# Out:
# Help on class TagHeuerData in module tagheuerdata:
#
# class TagHeuerData(builtins.object)
#  |  TagHeuerData(filename=None, player=None, courses=None)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, filename=None, player=None, courses=None)
#  |      Initialize the collection with a user.json file extracted from Tag Heuer App.
#  |
#  |      Parameter:
#  |      - filename: str, location of the source file
#  |      - player: str, email of the player to filter on one player
#  |      - courses: dataframe, a df which contains courses definition
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
tag = TagHeuerData('data/user.json')

# %%
tag.holes_played
# Out:
#       holeNumber  score.strokes  score.putts  score.penalties  \
# 0              1              6          2.0                0
# 1              2              5          2.0                0
# 2              3              3          2.0                0
# 3              4              5          2.0                0
# 4              5              5          2.0                0
# ...          ...            ...          ...              ...
# 1255          14              5          2.0                0
# 1256          15              4          2.0                0
# 1257          16              4          2.0                0
# 1258          17              7          2.0                0
# 1259          18              2          2.0                0
#
#      score.fairwayHit score.bunkerHit   rounddate        golfCourse firstName  \
# 0                None            None  2019-11-10  Golf de Gonville     Daryl
# ...
